# %%
# !poretools
# Out:
# usage: poretools [-h] [-v]
#                  {combine,fastq,fasta,stats,hist,events,readstats,tabular,nucdist,metadata,index,qualdist,qualpos,winner,squiggle,times,yield_plot,occupancy,organise}
#                  ...
# poretools: error: too few arguments

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
directory="Ectocooler_for_assembly/"

# %%
# !poretools stats -q $directory
# Out:
# total reads	46233
# total base pairs	162346411
# mean	3511.48
# median	2157
# min	130
# max	31659
# N25	10888
# N50	6453
# N75	3354

# %%
# !poretools stats -q --type fwd $directory
# Out:
# total reads	15427
# total base pairs	58938715
# mean	3820.49
# median	2351
# min	158
# max	31127
# N25	11687
# N50	7007
# N75	3623

# %%
# !poretools stats -q --type rev $directory
# Out:
# total reads	15427
# total base pairs	49100801
# mean	3182.78
# median	1931
# min	130
# max	28915
# N25	9858
# N50	5899
# N75	3046

# %%
# !poretools stats -q --type 2D $directory
# Out:
# total reads	15379
# total base pairs	54306895
# mean	3531.24
# median	2198
# min	134
# max	31659
# N25	10801
# N50	6451
# N75	3371

# %%
# !poretools hist -q --theme-bw --min-length 1000 --max-length 40000 --saveas hist.png $directory
# Out:
# INFO:poretools:100 files processed.
# INFO:poretools:200 files processed.
# INFO:poretools:300 files processed.
# INFO:poretools:400 files processed.
# INFO:poretools:500 files processed.
# INFO:poretools:600 files processed.
# INFO:poretools:700 files processed.
# INFO:poretools:800 files processed.
# INFO:poretools:900 files processed.
# INFO:poretools:1000 files processed.
# INFO:poretools:1100 files processed.
# INFO:poretools:1200 files processed.
# INFO:poretools:1300 files processed.
# INFO:poretools:1400 files processed.
# INFO:poretools:1500 files processed.
# INFO:poretools:1600 files processed.
# INFO:poretools:1700 files processed.
# INFO:poretools:1800 files processed.
# INFO:poretools:1900 files processed.
# INFO:poretools:2000 files processed.
# INFO:poretools:2100 files processed.
# INFO:poretools:2200 files processed.
# INFO:poretools:2300 files processed.
# INFO:poretools:2400 files processed.
# INFO:poretools:2500 files processed.
# INFO:poretools:2600 files processed.
# INFO:poretools:2700 files processed.
# INFO:poretools:2800 files processed.
# INFO:poretools:2900 files processed.
# INFO:poretools:3000 files processed.
# INFO:poretools:3100 files processed.
# INFO:poretools:3200 files processed.
# INFO:poretools:3300 files processed.
# INFO:poretools:3400 files processed.
# INFO:poretools:3500 files processed.
# INFO:poretools:3600 files processed.
# INFO:poretools:3700 files processed.
# INFO:poretools:3800 files processed.
# INFO:poretools:3900 files processed.
# INFO:poretools:4000 files processed.
# INFO:poretools:4100 files processed.
# INFO:poretools:4200 files processed.
# INFO:poretools:4300 files processed.
# INFO:poretools:4400 files processed.
# INFO:poretools:4500 files processed.
# INFO:poretools:4600 files processed.
# INFO:poretools:4700 files processed.
# INFO:poretools:4800 files processed.
# INFO:poretools:4900 files processed.
# INFO:poretools:5000 files processed.
# INFO:poretools:5100 files processed.
# INFO:poretools:5200 files processed.
# INFO:poretools:5300 files processed.
# INFO:poretools:5400 files processed.
# INFO:poretools:5500 files processed.
# INFO:poretools:5600 files processed.
# INFO:poretools:5700 files processed.
# INFO:poretools:5800 files processed.
# INFO:poretools:5900 files processed.
# INFO:poretools:6000 files processed.
# INFO:poretools:6100 files processed.
# INFO:poretools:6200 files processed.
# INFO:poretools:6300 files processed.
# INFO:poretools:6400 files processed.
# INFO:poretools:6500 files processed.
# INFO:poretools:6600 files processed.
# INFO:poretools:6700 files processed.
# INFO:poretools:6800 files processed.
# INFO:poretools:6900 files processed.
# INFO:poretools:7000 files processed.
# INFO:poretools:7100 files processed.
# INFO:poretools:7200 files processed.
# INFO:poretools:7300 files processed.
# INFO:poretools:7400 files processed.
# INFO:poretools:7500 files processed.
# INFO:poretools:7600 files processed.
# INFO:poretools:7700 files processed.
# INFO:poretools:7800 files processed.
# INFO:poretools:7900 files processed.
# INFO:poretools:8000 files processed.
# INFO:poretools:8100 files processed.
# INFO:poretools:8200 files processed.
# INFO:poretools:8300 files processed.
# INFO:poretools:8400 files processed.
# INFO:poretools:8500 files processed.
# INFO:poretools:8600 files processed.
# INFO:poretools:8700 files processed.
# INFO:poretools:8800 files processed.
# INFO:poretools:8900 files processed.
# INFO:poretools:9000 files processed.
# INFO:poretools:9100 files processed.
# INFO:poretools:9200 files processed.
# INFO:poretools:9300 files processed.
# INFO:poretools:9400 files processed.
# INFO:poretools:9500 files processed.
# INFO:poretools:9600 files processed.
# INFO:poretools:9700 files processed.
# INFO:poretools:9800 files processed.
# INFO:poretools:9900 files processed.
# INFO:poretools:10000 files processed.
# INFO:poretools:10100 files processed.
# INFO:poretools:10200 files processed.
# INFO:poretools:10300 files processed.
# INFO:poretools:10400 files processed.
# INFO:poretools:10500 files processed.
# INFO:poretools:10600 files processed.
# INFO:poretools:10700 files processed.
# INFO:poretools:10800 files processed.
# INFO:poretools:10900 files processed.
# INFO:poretools:11000 files processed.
# INFO:poretools:11100 files processed.
# INFO:poretools:11200 files processed.
# INFO:poretools:11300 files processed.
# INFO:poretools:11400 files processed.
# INFO:poretools:11500 files processed.
# INFO:poretools:11600 files processed.
# INFO:poretools:11700 files processed.
# INFO:poretools:11800 files processed.
# INFO:poretools:11900 files processed.
# INFO:poretools:12000 files processed.
# INFO:poretools:12100 files processed.
# INFO:poretools:12200 files processed.
# INFO:poretools:12300 files processed.
# INFO:poretools:12400 files processed.
# INFO:poretools:12500 files processed.
# INFO:poretools:12600 files processed.
# INFO:poretools:12700 files processed.
# INFO:poretools:12800 files processed.
# INFO:poretools:12900 files processed.
# INFO:poretools:13000 files processed.
# INFO:poretools:13100 files processed.
# INFO:poretools:13200 files processed.
# INFO:poretools:13300 files processed.
# INFO:poretools:13400 files processed.
# INFO:poretools:13500 files processed.
# INFO:poretools:13600 files processed.
# INFO:poretools:13700 files processed.
# INFO:poretools:13800 files processed.
# INFO:poretools:13900 files processed.
# INFO:poretools:14000 files processed.
# INFO:poretools:14100 files processed.
# INFO:poretools:14200 files processed.
# INFO:poretools:14300 files processed.
# INFO:poretools:14400 files processed.
# INFO:poretools:14500 files processed.
# INFO:poretools:14600 files processed.
# INFO:poretools:14700 files processed.
# INFO:poretools:14800 files processed.
# INFO:poretools:14900 files processed.
# INFO:poretools:15000 files processed.
# INFO:poretools:15100 files processed.
# INFO:poretools:15200 files processed.
# INFO:poretools:15300 files processed.
# INFO:poretools:15400 files processed.
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
Image("hist.png")
